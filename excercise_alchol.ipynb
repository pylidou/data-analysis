# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns',10)
pd.set_option('display.max_rows',10)

# %%
drinks = pd.read_csv('./data/drinks.csv',index_col=0)
drinks
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# ...

# %%
drinks.shape
# Out:
# (193, 5)

# %%
drinks.columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
con_grp = drinks.groupby('continent')

# %%
con_grp.total_litres_of_pure_alcohol.mean().sort_values(ascending=False).head(1)
# Out:
# continent
# EU    8.617778
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
k = con_grp.total_litres_of_pure_alcohol
k.mean(),k.var()
# Out:
# (continent
#  AF    3.007547
#  AS    2.170455
#  EU    8.617778
#  OC    3.381250
#  SA    6.308333
#  Name: total_litres_of_pure_alcohol, dtype: float64, continent
#  AF     7.009557
#  AS     7.674223
#  EU    11.279222
#  OC    11.193625
#  SA     2.344470
#  Name: total_litres_of_pure_alcohol, dtype: float64)

# %%
con_grp.mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
con_grp.median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85
